# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/CASIA-IVA-Lab/FastSAM.git
# Out:
# Cloning into 'FastSAM'...
# remote: Enumerating objects: 1221, done.
# remote: Counting objects: 100% (386/386), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 1221 (delta 334), reused 305 (delta 305), pack-reused 835
# Receiving objects: 100% (1221/1221), 72.46 MiB | 20.95 MiB/s, done.
# Resolving deltas: 100% (487/487), done.

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-yk7n1v67
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-yk7n1v67
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
# !pip install -r /content/FastSAM/requirements.txt

# %%
# !pip
# Out:
# Usage:
#   pip3 <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
# ...

# %%
# !pip install clip

# %%
# !python Inference.py --model_path ./weights/FastSAM.pt --img_path ./images/dogs.jpg

# %%
# !python /content/FastSAM/Inference.py --model_path /content/FastSAM/weights/FastSAM-s.pt --img_path /content/FastSAM/images/cat.jpg --text_prompt "the cat"
# Out:
# 2024-06-09 11:32:38.019942: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 11:32:38.020008: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 11:32:38.021312: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# 0: 1024x576 25 objects, 151.5ms
# Speed: 8.6ms preprocess, 151.5ms inference, 579.2ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
# !unzip -q tmp.zip -d ./content/Ball_Detect.v1i.yolov8.zip
# Out:
# unzip:  cannot find or open tmp.zip, tmp.zip.zip or tmp.zip.ZIP.

# %%
# !python Vid_Inference.py --model_path ./weights/FastSAM-s.pt --video_path ./videos/input.mp4
# Out:
# Processing frame 1
# 2024-05-13 08:18:51.341987: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-13 08:18:51.342042: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-13 08:18:51.343367: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# 0: 576x1024 35 objects, 269.4ms
# Speed: 11.7ms preprocess, 269.4ms inference, 866.8ms postprocess per image at shape (1, 3, 1024, 1024)
# Traceback (most recent call last):
#   File "/content/FastSAM/Vid_Inference.py", line 146, in <module>
#     main(args)
# ...

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/FastSAM/LiveFastSAM.py"
# Out:
# ...
# 100% 138M/138M [00:02<00:00, 68.2MB/s]
# cuda
# [ WARN:0@9.547] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# [ERROR:0@9.547] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range

# %%
# !python train_fastsam.py --train_path {train_path} --val_path {val_path} --test_path {test_path} --num_classes {nc} --class_names {names}
# Out:
# Text read from the file:
# This is some appended text.

# %%
# !unzip /content/tt.v2i.yolov8.zip -d /content/DataSet
# Out:
# Archive:  /content/tt.v2i.yolov8.zip
#  extracting: /content/DataSet/README.dataset.txt
#  extracting: /content/DataSet/README.roboflow.txt
#  extracting: /content/DataSet/data.yaml
#    creating: /content/DataSet/test/
#    creating: /content/DataSet/test/images/
#  extracting: /content/DataSet/test/images/-2021-10-22-162147_jpg.rf.4ddd5dec3128eecd27d7d19b4a4221ce.jpg
#  extracting: /content/DataSet/test/images/-2021-10-22-162147_jpg.rf.7753314cf4647bb5f98bea3c70a6ca7c.jpg
#  extracting: /content/DataSet/test/images/073_jpg.rf.405c14bbcc2dbda2bfd683179b89c08c.jpg
#  extracting: /content/DataSet/test/images/092_jpg.rf.c42c989e5d26c33e98c2038497207cb8.jpg
#  extracting: /content/DataSet/test/images/12_jpg.rf.0a4f202d4a7c567715c91fef0a1465a7.jpg
#  extracting: /content/DataSet/test/images/13_jpg.rf.c1ff294df5d790490bf707ac257b58c7.jpg
#  extracting: /content/DataSet/test/images/14_jpg.rf.29d95287151901d7c5deb78c1e65a34b.jpg
# ...

# %%
# !python /content/FastSAM/train.py --train_path {train_path} --num_classes {nc} --class_names {names}
